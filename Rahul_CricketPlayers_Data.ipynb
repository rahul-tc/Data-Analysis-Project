# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul-tc/Data-Analysis-Project/blob/main/Rahul_CricketPlayers_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You have been provided with a dataset containing the details of cricket players from various countries who have played in World Cup matches. The link below gives you access to the data for further analysis.
#
# url: https://raw.githubusercontent.com/Invact-Abhay/DOE/refs/heads/main/Cricket%20Player%20Details%20-%20Data.csv

# %% [markdown]
# # **PF2.1**

# %% [markdown]
# ***Task 1: Import the pandas library.***

# %%
import pandas as pd

# %% [markdown]
# ***Task 2: Create a DataFrame named 'cpdata' from the given URL and then print the first 5 rows to understand the data.***

# %%
cpdata = pd.read_csv('https://raw.githubusercontent.com/Invact-Abhay/DOE/refs/heads/main/Cricket%20Player%20Details%20-%20Data.csv')
cpdata.head()
# Out:
#               Player       Country  Matches  Innings  NotOuts  Runs  \
# 0  Sachin Tendulkar          India       45       44        4  2278
# 1  DPMD Jayawardene      Sri Lanka       40       34        3  1100
# 2     ST Jayasuriya      Sri Lanka       38       37        3  1165
# 3        RT Ponting      Australia       46       42        4  1743
# 4    AB de Villiers   South Africa       23       22        3  1207
#
#    HighestScore
# 0           152
# 1           115
# 2           120
# 3           140
# 4           162

# %% [markdown]
# ***Task 3: Retrieve all details of cricketers who have scored 1,500 runs or more.***

# %%
cpdata.query('Runs >= 1500')
# Out:
#               Player    Country  Matches  Innings  NotOuts  Runs  HighestScore
# 0  Sachin Tendulkar       India       45       44        4  2278           152
# 3        RT Ponting   Australia       46       42        4  1743           140
# 5     KC Sangakkara   Sri Lanka       37       35        8  1532           124

# %% [markdown]
# ***Task 4: Retrieve the details of all Indian cricketers.***

# %%
cpdata.query('Country == "India"')
# Out:
#                Player Country  Matches  Innings  NotOuts  Runs  HighestScore
# 0   Sachin Tendulkar    India       45       44        4  2278           152
# 10      M Azharuddin    India       30       25        4   826            93
# 21          MS Dhoni    India       29       25        7   780            91
# 23           V Kohli    India       26       26        4  1030           107
# 29          R Dravid    India       22       21        7   860           145
# 38          V Sehwag    India       22       22        0   843           175
# 43        SC Ganguly    India       21       21        3  1006           183
# 48         RG Sharma    India       17       17        2   978           140

# %% [markdown]
# ***Task 5: Retrieve the details of Sri Lankan players whose highest score is greater than 120.***

# %%
cpdata.query('Country == "Sri Lanka" & HighestScore >120')
# Out:
#             Player    Country  Matches  Innings  NotOuts  Runs  HighestScore
# 5   KC Sangakkara   Sri Lanka       37       35        8  1532           124
# 6     PA de Silva   Sri Lanka       35       32        3  1064           145
# 22     TM Dilshan   Sri Lanka       27       25        4  1112           161

# %% [markdown]
# ***Task 6: Retrieve the details of cricketers who have either played fewer than 15 matches or whose highest score is less than 100.***

# %%
cpdata.query('Matches<15 or HighestScore<100')
# Out:
#            Player       Country  Matches  Innings  NotOuts  Runs  HighestScore
# 8    A Ranatunga      Sri Lanka       30       29        8   969            88
# 10  M Azharuddin          India       30       25        4   826            93
# 21      MS Dhoni          India       29       25        7   780            91
# 44     MJ Clarke      Australia       25       21        7   888            93
# 45     SO Tikolo          Kenya       28       27        1   768            96
# 47      GC Smith   South Africa       20       20        1   747            91

# %% [markdown]
# ***Task 7: Retrieve the details of cricketers from England or Bangladesh.***

# %%
cpdata.query('Country == "England" or Country == "Bangladesh"')
# Out:
#               Player     Country  Matches  Innings  NotOuts  Runs  \
# 13  Shakib Al Hasan   Bangladesh       29       29        4  1146
# 14          JE Root      England       17       16        2   758
# 16  Mushfiqur Rahim   Bangladesh       29       28        5   877
# 33         GA Gooch      England       21       21        1   897
#
#     HighestScore
# 13           124
# 14           121
# 16           102
# 33           115

# %% [markdown]
# ***Task 8: Retrieve all the details of the player who has played the maximum number of matches.***

# %%
cpdata.query('Matches == Matches.max()')
# Out:
#         Player    Country  Matches  Innings  NotOuts  Runs  HighestScore
# 3  RT Ponting   Australia       46       42        4  1743           140

# %% [markdown]
# ***Task 9: Retrieve all details of the player who has played the fewest innings.***

# %%
cpdata.query('Innings == Innings.min()')
# Out:
#       Player    Country  Matches  Innings  NotOuts  Runs  HighestScore
# 14  JE Root     England       17       16        2   758           121
# 26  DC Boon   Australia       16       16        1   815           100

# %% [markdown]
# ***Task 10: Retrieve the details of the players from India or Sri Lanka who have played more than 30 matches.***

# %%
#cpdata.query('Country == "India" or Country == "Sri Lanka" & Matches>30') - implement filter but only on Sri Lanka not on India
cpdata.query('Country in ["India","Sri Lanka"] & Matches>30')
# Out:
#               Player    Country  Matches  Innings  NotOuts  Runs  HighestScore
# 0  Sachin Tendulkar       India       45       44        4  2278           152
# 1  DPMD Jayawardene   Sri Lanka       40       34        3  1100           115
# 2     ST Jayasuriya   Sri Lanka       38       37        3  1165           120
# 5     KC Sangakkara   Sri Lanka       37       35        8  1532           124
# 6       PA de Silva   Sri Lanka       35       32        3  1064           145

# %% [markdown]
# ***Task 11: Find the cricketer who has scored maximum runs.***

# %%
cpdata.query('Runs == Runs.max()')
# Out:
#               Player Country  Matches  Innings  NotOuts  Runs  HighestScore
# 0  Sachin Tendulkar    India       45       44        4  2278           152

# %% [markdown]
# ***Task 12: Retrieve the list of Indian cricketers along with the runs they have scored.***

# %%
cpdata.query('Country == "India"')[['Player','Runs']]
# Out:
#                Player  Runs
# 0   Sachin Tendulkar   2278
# 10      M Azharuddin    826
# 21          MS Dhoni    780
# 23           V Kohli   1030
# 29          R Dravid    860
# 38          V Sehwag    843
# 43        SC Ganguly   1006
# 48         RG Sharma    978

# %% [markdown]
# # **PF2.2**

# %% [markdown]
# ***Task 13: Sort the data by country names in ascending order.***

# %%
cpdata.sort_values('Country',ascending=True)
# Out:
#                Player       Country  Matches  Innings  NotOuts  Runs  \
# 9          DA Warner      Australia       18       18        2   992
# 44         MJ Clarke      Australia       25       21        7   888
# 26           DC Boon      Australia       16       16        1   815
# 3         RT Ponting      Australia       46       42        4  1743
# 37          SR Waugh      Australia       33       30       10   978
# 35      AC Gilchrist      Australia       31       31        1  1085
# 7           ME Waugh      Australia       22       22        3  1004
# 15         ML Hayden      Australia       22       21        2   987
# 32         SPD Smith      Australia       24       20        2   834
# 12          AJ Finch      Australia       18       18        0   787
# 16   Mushfiqur Rahim     Bangladesh       29       28        5   877
# 13   Shakib Al Hasan     Bangladesh       29       29        4  1146
# 33          GA Gooch        England       21       21        1   897
# 14           JE Root        England       17       16        2   758
# 0   Sachin Tendulkar          India       45       44        4  2278
# 23           V Kohli          India       26       26        4  1030
# 38          V Sehwag          India       22       22        0   843
# 43        SC Ganguly          India       21       21        3  1006
# 29          R Dravid          India       22       21        7   860
# 21          MS Dhoni          India       29       25        7   780
# 48         RG Sharma          India       17       17        2   978
# 10      M Azharuddin          India       30       25        4   826
# 45         SO Tikolo          Kenya       28       27        1   768
# 34          MD Crowe    New Zealand       21       21        5   880
# 39       LRPL Taylor    New Zealand       33       30        3  1002
# 20         SB Styris    New Zealand       26       22        5   909
# 27        SP Fleming    New Zealand       33       33        3  1075
# 28        MJ Guptill    New Zealand       27       27        4   995
# 30     KS Williamson    New Zealand       23       22        6   911
# 46       Saeed Anwar       Pakistan       21       21        4   915
# 40         G Kirsten   South Africa       21       21        4   806
# 4     AB de Villiers   South Africa       23       22        3  1207
# 31         JH Kallis   South Africa       36       32        7  1148
# 17          HH Gibbs   South Africa       25       23        4  1067
# 25           HM Amla   South Africa       22       22        2   842
# 47          GC Smith   South Africa       20       20        1   747
# 18      F du Plessis   South Africa       23       21        5   926
# 8        A Ranatunga      Sri Lanka       30       29        8   969
# 6        PA de Silva      Sri Lanka       35       32        3  1064
# 5      KC Sangakkara      Sri Lanka       37       35        8  1532
# 22        TM Dilshan      Sri Lanka       27       25        4  1112
# 1   DPMD Jayawardene      Sri Lanka       40       34        3  1100
# 2      ST Jayasuriya      Sri Lanka       38       37        3  1165
# 19           BC Lara   West Indies        34       33        4  1225
# 36     S Chanderpaul   West Indies        31       28        4   970
# 11      IVA Richards   West Indies        23       21        5  1013
# 42         DL Haynes   West Indies        25       25        2   854
# 24          CH Gayle   West Indies        35       34        1  1186
# 41          A Flower            Zim       30       29        4   815
#
#     HighestScore
# 9            178
# 44            93
# 26           100
# 3            140
# 37           120
# 35           149
# 7            130
# 15           158
# 32           105
# 12           153
# 16           102
# 13           124
# 33           115
# 14           121
# 0            152
# 23           107
# 38           175
# 43           183
# 29           145
# 21            91
# 48           140
# 10            93
# 45            96
# 34           100
# 39           131
# 20           141
# 27           134
# 28           237
# 30           148
# 46           113
# 40           188
# 4            162
# 31           128
# 17           143
# 25           159
# 47            91
# 18           109
# 8             88
# 6            145
# 5            124
# 22           161
# 1            115
# 2            120
# 19           116
# 36           102
# 11           181
# 42           105
# 24           215
# 41           115

# %% [markdown]
# ***Task 14: Sort the data by highest score in descending order.***

# %%
cpdata.sort_values('HighestScore',ascending=False)
# Out:
#                Player       Country  Matches  Innings  NotOuts  Runs  \
# 28        MJ Guptill    New Zealand       27       27        4   995
# 24          CH Gayle   West Indies        35       34        1  1186
# 40         G Kirsten   South Africa       21       21        4   806
# 43        SC Ganguly          India       21       21        3  1006
# 11      IVA Richards   West Indies        23       21        5  1013
# 9          DA Warner      Australia       18       18        2   992
# 38          V Sehwag          India       22       22        0   843
# 4     AB de Villiers   South Africa       23       22        3  1207
# 22        TM Dilshan      Sri Lanka       27       25        4  1112
# 25           HM Amla   South Africa       22       22        2   842
# 15         ML Hayden      Australia       22       21        2   987
# 12          AJ Finch      Australia       18       18        0   787
# 0   Sachin Tendulkar          India       45       44        4  2278
# 35      AC Gilchrist      Australia       31       31        1  1085
# 30     KS Williamson    New Zealand       23       22        6   911
# 29          R Dravid          India       22       21        7   860
# 6        PA de Silva      Sri Lanka       35       32        3  1064
# 17          HH Gibbs   South Africa       25       23        4  1067
# 20         SB Styris    New Zealand       26       22        5   909
# 48         RG Sharma          India       17       17        2   978
# 3         RT Ponting      Australia       46       42        4  1743
# 27        SP Fleming    New Zealand       33       33        3  1075
# 39       LRPL Taylor    New Zealand       33       30        3  1002
# 7           ME Waugh      Australia       22       22        3  1004
# 31         JH Kallis   South Africa       36       32        7  1148
# 13   Shakib Al Hasan     Bangladesh       29       29        4  1146
# 5      KC Sangakkara      Sri Lanka       37       35        8  1532
# 14           JE Root        England       17       16        2   758
# 2      ST Jayasuriya      Sri Lanka       38       37        3  1165
# 37          SR Waugh      Australia       33       30       10   978
# 19           BC Lara   West Indies        34       33        4  1225
# 33          GA Gooch        England       21       21        1   897
# 41          A Flower            Zim       30       29        4   815
# 1   DPMD Jayawardene      Sri Lanka       40       34        3  1100
# 46       Saeed Anwar       Pakistan       21       21        4   915
# 18      F du Plessis   South Africa       23       21        5   926
# 23           V Kohli          India       26       26        4  1030
# 32         SPD Smith      Australia       24       20        2   834
# 42         DL Haynes   West Indies        25       25        2   854
# 36     S Chanderpaul   West Indies        31       28        4   970
# 16   Mushfiqur Rahim     Bangladesh       29       28        5   877
# 34          MD Crowe    New Zealand       21       21        5   880
# 26           DC Boon      Australia       16       16        1   815
# 45         SO Tikolo          Kenya       28       27        1   768
# 10      M Azharuddin          India       30       25        4   826
# 44         MJ Clarke      Australia       25       21        7   888
# 21          MS Dhoni          India       29       25        7   780
# 47          GC Smith   South Africa       20       20        1   747
# 8        A Ranatunga      Sri Lanka       30       29        8   969
#
#     HighestScore
# 28           237
# 24           215
# 40           188
# 43           183
# 11           181
# 9            178
# 38           175
# 4            162
# 22           161
# 25           159
# 15           158
# 12           153
# 0            152
# 35           149
# 30           148
# 29           145
# 6            145
# 17           143
# 20           141
# 48           140
# 3            140
# 27           134
# 39           131
# 7            130
# 31           128
# 13           124
# 5            124
# 14           121
# 2            120
# 37           120
# 19           116
# 33           115
# 41           115
# 1            115
# 46           113
# 18           109
# 23           107
# 32           105
# 42           105
# 36           102
# 16           102
# 34           100
# 26           100
# 45            96
# 10            93
# 44            93
# 21            91
# 47            91
# 8             88

# %% [markdown]
# ***Task 15: List the top 5 players based on the runs they have scored, with the players who have the highest runs at the top.***

# %%
cpdata.sort_values('Runs',ascending=False).head()
# Out:
#                Player       Country  Matches  Innings  NotOuts  Runs  \
# 0   Sachin Tendulkar          India       45       44        4  2278
# 3         RT Ponting      Australia       46       42        4  1743
# 5      KC Sangakkara      Sri Lanka       37       35        8  1532
# 19           BC Lara   West Indies        34       33        4  1225
# 4     AB de Villiers   South Africa       23       22        3  1207
#
#     HighestScore
# 0            152
# 3            140
# 5            124
# 19           116
# 4            162

# %% [markdown]
# ***Task 16: Retrieve the details of players from Bangladesh and sort the results by highest score in descending order.***

# %%
cpdata.query('Country == "Bangladesh"').sort_values('HighestScore',ascending=False)
# Out:
#               Player     Country  Matches  Innings  NotOuts  Runs  \
# 13  Shakib Al Hasan   Bangladesh       29       29        4  1146
# 16  Mushfiqur Rahim   Bangladesh       29       28        5   877
#
#     HighestScore
# 13           124
# 16           102

# %% [markdown]
# ***Task 17: Find the details of players who have played more than 40 innings and sort the results based on the player's names in alphabetical order.***

# %%
cpdata.query('Innings>40').sort_values('Player')
# Out:
#               Player    Country  Matches  Innings  NotOuts  Runs  HighestScore
# 3        RT Ponting   Australia       46       42        4  1743           140
# 0  Sachin Tendulkar       India       45       44        4  2278           152

# %% [markdown]
# ***Task 18: List the top 5 players along with their country based on the runs scored and are from South Africa or Sri Lanka.***

# %%
#cpdata.query('Country in ["South Africa", "Sri Lanka"]').sort_values('Runs',ascending=False).head()
cpdata.query('Country in ["South Africa", "Sri Lanka"]').sort_values('Runs',ascending=False)[["Player","Country"]].head()
# Out:
#              Player       Country
# 5    KC Sangakkara      Sri Lanka
# 4   AB de Villiers   South Africa
# 2    ST Jayasuriya      Sri Lanka
# 31       JH Kallis   South Africa
# 22      TM Dilshan      Sri Lanka
