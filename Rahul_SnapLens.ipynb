# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul-tc/Data-Analysis-Project/blob/main/Rahul_SnapLens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
budget = pd.read_csv("https://raw.githubusercontent.com/Invact-Abhay/DOE/refs/heads/main/BudgetTable.csv")
budget.head()
# Out:
#      Month Region   State Product Category  Budgeted Quantity
# 0  January  North   Delhi     Professional                 50
# 1  January  North   Delhi        Lifestyle                 50
# 2  January  North   Delhi        Adventure                 50
# 3  January  North  Punjab     Professional                 50
# 4  January  North  Punjab        Lifestyle                110

# %%
transaction = pd.read_csv("https://raw.githubusercontent.com/Invact-Abhay/DOE/refs/heads/main/ActualTable.csv")
transaction.head()
# Out:
#         Date    Month Region  State Product Category  Quantity Sold
# 0  1/27/2023  January  North  Delhi     Professional             10
# 1  1/21/2023  January  North  Delhi     Professional             60
# 2  1/24/2023  January  North  Delhi     Professional             40
# 3  1/20/2023  January  North  Delhi     Professional             40
# 4  1/16/2023  January  North  Delhi     Professional             30

# %%
budget.columns
budget.columns = budget.columns.str.lower().str.replace(" ","_")
budget.columns
# Out:
# Index(['month', 'region', 'state', 'product_category', 'budgeted_quantity'], dtype='object')

# %%
transaction.columns
transaction.columns = transaction.columns.str.lower().str.replace(" ","_")
transaction.columns
# Out:
# Index(['date', 'month', 'region', 'state', 'product_category',
#        'quantity_sold'],
#       dtype='object')

# %%
actual = transaction.groupby(['month','region','state','product_category'])['quantity_sold'].sum().reset_index()
actual
# Out:
#          month region        state product_category  quantity_sold
# 0        April  North        Delhi        Adventure            130
# 1        April  North        Delhi        Lifestyle             60
# 2        April  North        Delhi     Professional             60
# 3        April  North      Haryana        Adventure             10
# 4        April  North      Haryana        Lifestyle            180
# ..         ...    ...          ...              ...            ...
# 317  September   West  Maharashtra        Lifestyle            230
# 318  September   West  Maharashtra     Professional            210
# 319  September   West    Rajasthan        Adventure            250
# 320  September   West    Rajasthan        Lifestyle            100
# 321  September   West    Rajasthan     Professional            260
#
# [322 rows x 5 columns]

# %%
merged_table = pd.merge(budget, actual, on=['month','region','state','product_category'], how='left')
print(merged_table.head())
# Out:
#      month region   state product_category  budgeted_quantity  quantity_sold
# 0  January  North   Delhi     Professional                 50          230.0
# 1  January  North   Delhi        Lifestyle                 50          130.0
# 2  January  North   Delhi        Adventure                 50          280.0
# 3  January  North  Punjab     Professional                 50          120.0
# 4  January  North  Punjab        Lifestyle                110          150.0

# %%
merged_table['variance'] = merged_table['quantity_sold']-merged_table['budgeted_quantity']
#merged_table.head()
merged_table
# Out:
#         month region      state product_category  budgeted_quantity  \
# 0     January  North      Delhi     Professional                 50
# 1     January  North      Delhi        Lifestyle                 50
# 2     January  North      Delhi        Adventure                 50
# 3     January  North     Punjab     Professional                 50
# 4     January  North     Punjab        Lifestyle                110
# ..        ...    ...        ...              ...                ...
# 319  December   West    Gujarat        Lifestyle                150
# 320  December   West    Gujarat        Adventure                310
# 321  December   West  Rajasthan     Professional                120
# 322  December   West  Rajasthan        Lifestyle                290
# 323  December   West  Rajasthan        Adventure                160
#
#      quantity_sold  variance
# 0            230.0     180.0
# 1            130.0      80.0
# 2            280.0     230.0
# 3            120.0      70.0
# 4            150.0      40.0
# ..             ...       ...
# 319          110.0     -40.0
# 320           40.0    -270.0
# 321           50.0     -70.0
# 322           10.0    -280.0
# 323          150.0     -10.0
#
# [324 rows x 7 columns]

# %%
month_mapping = {'January':1,
                 'February':2,
                 'March':3,
                 'April':4,
                 'May':5,
                 'June':6,
                 'July':7,
                 'August':8,
                 'September':9,
                 'October':10,
                 'November':11,
                 'December':12}
merged_table['month_number'] = merged_table['month'].map(month_mapping)
merged_table
# Out:
#         month region      state product_category  budgeted_quantity  \
# 0     January  North      Delhi     Professional                 50
# 1     January  North      Delhi        Lifestyle                 50
# 2     January  North      Delhi        Adventure                 50
# 3     January  North     Punjab     Professional                 50
# 4     January  North     Punjab        Lifestyle                110
# ..        ...    ...        ...              ...                ...
# 319  December   West    Gujarat        Lifestyle                150
# 320  December   West    Gujarat        Adventure                310
# 321  December   West  Rajasthan     Professional                120
# 322  December   West  Rajasthan        Lifestyle                290
# 323  December   West  Rajasthan        Adventure                160
#
#      quantity_sold  variance  month_number
# 0            230.0     180.0             1
# 1            130.0      80.0             1
# 2            280.0     230.0             1
# 3            120.0      70.0             1
# 4            150.0      40.0             1
# ..             ...       ...           ...
# 319          110.0     -40.0            12
# 320           40.0    -270.0            12
# 321           50.0     -70.0            12
# 322           10.0    -280.0            12
# 323          150.0     -10.0            12
#
# [324 rows x 8 columns]

# %%
monthly_variance = merged_table.groupby(['month','month_number'])['variance'].sum().reset_index()
sorted_monthly_variance = monthly_variance.sort_values('month_number')
sorted_monthly_variance
# Out:
#         month  month_number  variance
# 4     January             1    1310.0
# 3    February             2     440.0
# 7       March             3     640.0
# 0       April             4    -160.0
# 8         May             5    -340.0
# 6        June             6   -1040.0
# 5        July             7    -600.0
# 1      August             8    -770.0
# 11  September             9     180.0
# 10    October            10   -2070.0
# 9    November            11    1350.0
# 2    December            12    -870.0

# %%
plt.bar(x=sorted_monthly_variance['month'],height = sorted_monthly_variance['variance'])
plt.xlabel('month')
plt.ylabel('variance')
plt.title('monthly sales variance (in unit sold)')
plt.xticks(ticks=sorted_monthly_variance['month'], rotation =90)
plt.show()

# %%
regionwise_variance = merged_table.groupby(['region'])['variance'].sum().reset_index()
regionwise_variance
# Out:
#   region  variance
# 0  North    -720.0
# 1  South    -860.0
# 2   West    -350.0

# %%
plt.bar(x= regionwise_variance['region'],height= regionwise_variance['variance'])
plt.show()

# %%
plt.bar(x= regionwise_variance['region'],height= regionwise_variance['variance'])
plt.xlabel('region')
plt.ylabel('variance')
plt.title('regionwise sales variance (in unit sold)')
plt.show()

# %%
statewise_variance = merged_table.groupby(['state'])['variance'].sum().reset_index()
statewise_variance
# Out:
#          state  variance
# 0        Delhi    -140.0
# 1      Gujarat    -120.0
# 2      Haryana    -500.0
# 3    Karnataka     750.0
# 4       Kerala     210.0
# 5  Maharashtra     480.0
# 6       Punjab     -80.0
# 7    Rajasthan    -710.0
# 8   Tamil Nadu   -1820.0

# %%
plt.bar(x= statewise_variance['state'],height= statewise_variance['variance'])
plt.xlabel('state')
plt.ylabel('variance')
plt.title('statewise variance (in unit sold)')
plt.xticks(ticks=statewise_variance['state'], rotation =90)
plt.show()
