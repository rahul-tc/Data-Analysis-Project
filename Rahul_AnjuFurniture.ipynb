# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul-tc/Data-Analysis-Project/blob/main/Rahul_AnjuFurniture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
product_return = pd.read_csv("https://raw.githubusercontent.com/Invact-Abhay/DOE/refs/heads/main/SalesReturnTable.csv")
product_return
product_return.head() #this will give top 5 data values
# Out:
#    TransactionID    ProductName            Reason  Price/Unit  SalesValue  \
# 0           3627  Dining Tables        Wrong Size       30000       30000
# 1           3628     Bed Frames  Damage or Defect       20000       40000
# 2           3629     Bed Frames        Wrong Size       20000       20000
# 3           3630     Bed Frames  Damage or Defect       20000       40000
# 4           3631       Dressers        Wrong Size       18000       18000
#
#    Returns
# 0        1
# 1        2
# 2        1
# 3        2
# 4        1

# %%
total_return = product_return.groupby("ProductName")["Returns"].sum()
total_return
# Out:
# ProductName
# Bed Frames           406
# Bookcases             72
# Coffee Tables        168
# Desks                 43
# Dining Chairs        129
# Dining Tables        603
# Dressers              90
# Mattresses           123
# Nightstands           61
# Office Chairs         28
# Ottomans               7
# Recliners            182
# Sofas and Couches    187
# TV Stands             25
# Wardrobes             93
# Name: Returns, dtype: int64

# %%
sorted_returns = total_return.sort_values(ascending=False)
sorted_returns
# Out:
# ProductName
# Dining Tables        603
# Bed Frames           406
# Sofas and Couches    187
# Recliners            182
# Coffee Tables        168
# Dining Chairs        129
# Mattresses           123
# Wardrobes             93
# Dressers              90
# Bookcases             72
# Nightstands           61
# Desks                 43
# Office Chairs         28
# TV Stands             25
# Ottomans               7
# Name: Returns, dtype: int64

# %%
cumulative_sum = sorted_returns.cumsum()
cumulative_sum
# Out:
# ProductName
# Dining Tables         603
# Bed Frames           1009
# Sofas and Couches    1196
# Recliners            1378
# Coffee Tables        1546
# Dining Chairs        1675
# Mattresses           1798
# Wardrobes            1891
# Dressers             1981
# Bookcases            2053
# Nightstands          2114
# Desks                2157
# Office Chairs        2185
# TV Stands            2210
# Ottomans             2217
# Name: Returns, dtype: int64

# %%
cumulative_percentage = cumulative_sum/sorted_returns.sum()
cumulative_percentage
# Out:
# ProductName
# Dining Tables        0.271989
# Bed Frames           0.455120
# Sofas and Couches    0.539468
# Recliners            0.621561
# Coffee Tables        0.697339
# Dining Chairs        0.755525
# Mattresses           0.811006
# Wardrobes            0.852954
# Dressers             0.893550
# Bookcases            0.926026
# Nightstands          0.953541
# Desks                0.972936
# Office Chairs        0.985566
# TV Stands            0.996843
# Ottomans             1.000000
# Name: Returns, dtype: float64

# %%
cumulative_percentage = cumulative_sum/sorted_returns.sum()*100
cumulative_percentage
# Out:
# ProductName
# Dining Tables         27.198917
# Bed Frames            45.511953
# Sofas and Couches     53.946775
# Recliners             62.156067
# Coffee Tables         69.733875
# Dining Chairs         75.552548
# Mattresses            81.100586
# Wardrobes             85.295444
# Dressers              89.354984
# Bookcases             92.602616
# Nightstands           95.354082
# Desks                 97.293640
# Office Chairs         98.556608
# TV Stands             99.684258
# Ottomans             100.000000
# Name: Returns, dtype: float64

# %%
cumulative_percentage = round(cumulative_sum/sorted_returns.sum()*100,2)
cumulative_percentage
# Out:
# ProductName
# Dining Tables         27.20
# Bed Frames            45.51
# Sofas and Couches     53.95
# Recliners             62.16
# Coffee Tables         69.73
# Dining Chairs         75.55
# Mattresses            81.10
# Wardrobes             85.30
# Dressers              89.35
# Bookcases             92.60
# Nightstands           95.35
# Desks                 97.29
# Office Chairs         98.56
# TV Stands             99.68
# Ottomans             100.00
# Name: Returns, dtype: float64

# %%
fig, ax1 = plt.subplots()
sorted_returns.plot(kind='bar',color='C0',ax=ax1)
ax1.set_ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %%
fig, ax1 = plt.subplots()
sorted_returns.plot(kind='bar',color='C0',ax=ax1)
ax1.set_ylabel('Returns')
ax2 = ax1.twinx()
cumulative_percentage.plot(kind='line',color='C1',ax=ax2,marker='D')
ax2.set_ylabel('cumulative_percentage%')
plt.title('Pareto Analysis of Product Return')
# Out:
# Text(0.5, 1.0, 'Pareto Analysis of Product Return')

# %%
product_return.head()
# Out:
#    TransactionID    ProductName            Reason  Price/Unit  SalesValue  \
# 0           3627  Dining Tables        Wrong Size       30000       30000
# 1           3628     Bed Frames  Damage or Defect       20000       40000
# 2           3629     Bed Frames        Wrong Size       20000       20000
# 3           3630     Bed Frames  Damage or Defect       20000       40000
# 4           3631       Dressers        Wrong Size       18000       18000
#
#    Returns
# 0        1
# 1        2
# 2        1
# 3        2
# 4        1

# %%
Top4 = product_return.query('ProductName in["Dining Tables","Bed Frames","Sofas and Couches","Recliners"]')
Top4
# Out:
#       TransactionID        ProductName            Reason  Price/Unit  \
# 0              3627      Dining Tables        Wrong Size       30000
# 1              3628         Bed Frames  Damage or Defect       20000
# 2              3629         Bed Frames        Wrong Size       20000
# 3              3630         Bed Frames  Damage or Defect       20000
# 5              3632  Sofas and Couches     Late Delivery       50000
# ...             ...                ...               ...         ...
# 1467           5094         Bed Frames  Damage or Defect       20000
# 1468           5095      Dining Tables        Wrong Size       30000
# 1469           5096         Bed Frames  Damage or Defect       20000
# 1470           5097      Dining Tables        Wrong Size       30000
# 1471           5098         Bed Frames  Damage or Defect       20000
#
#       SalesValue  Returns
# 0          30000        1
# 1          40000        2
# 2          20000        1
# 3          40000        2
# 5          50000        1
# ...          ...      ...
# 1467       20000        1
# 1468       60000        2
# 1469       20000        1
# 1470       60000        2
# 1471       20000        1
#
# [904 rows x 6 columns]

# %%
sorted_reasons1 = Top4.groupby("Reason")["Returns"].sum().sort_values(ascending=False)
sorted_reasons1
# Out:
# Reason
# Wrong Size              612
# Damage or Defect        480
# Comfort Issues           74
# Assembly Issues          56
# Poor Quality             55
# Color/Style Mismatch     45
# Late Delivery            34
# Change of Mind           22
# Name: Returns, dtype: int64

# %%
cumulative_reason_percentage = sorted_reasons1.cumsum()/sorted_reasons1.sum()
cumulative_reason_percentage
# Out:
# Reason
# Wrong Size              0.444122
# Damage or Defect        0.792453
# Comfort Issues          0.846154
# Assembly Issues         0.886792
# Poor Quality            0.926705
# Color/Style Mismatch    0.959361
# Late Delivery           0.984035
# Change of Mind          1.000000
# Name: Returns, dtype: float64

# %%
cumulative_reason_percentage = round(sorted_reasons1.cumsum()/sorted_reasons1.sum()*100,2)
cumulative_reason_percentage
# Out:
# Reason
# Wrong Size               44.41
# Damage or Defect         79.25
# Comfort Issues           84.62
# Assembly Issues          88.68
# Poor Quality             92.67
# Color/Style Mismatch     95.94
# Late Delivery            98.40
# Change of Mind          100.00
# Name: Returns, dtype: float64

# %%
fig, ax1=plt.subplots()
sorted_reasons1.plot(kind='bar',color='C0',ax=ax1)
ax1.set_ylabel('Returns')
ax2 = ax1.twinx()
cumulative_reason_percentage.plot(kind ='line', color='C1',ax=ax2,marker='D')
ax2.set_ylabel('Cumulative Percentage %')
plt.title('Pareto Analysis of the reasons associated with returns')
# Out:
# Text(0.5, 1.0, 'Pareto Analysis of the reasons associated with returns')
